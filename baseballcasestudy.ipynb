# %% [markdown]
# # Baseball Case Study
# Problem Statement:
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# - Output: Number of predicted wins (W)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors

# %%
df.shape
# Out:
# (30, 17)

# %% [raw]
# The input features says:
#
#     R               -    Runs
#     AB              -    At Bats
#     H               -    Hits
#     2B              -    Doubles
#     3B              -    Triples
#     HR              -    Homeruns
#     W               -    Walks
#     SO              -    Strikeouts
#     SB              -    StolenBases
#     RA              -    Runs Allowed
#     ER              -    Earned Runs
#     ERA             -    Earned Runs Average
#     CG              -    Complete games
#     SHO             -    Shutouts
#     SV              -    Saves
#     E               -    Errors

# %% [markdown]
# There are total  16 features given for predicting the wins.the total no of rows are 30

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# There are 16 columns present in the data

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# All the features are of type integer except ERA which is a float type, as it is a average it is taking as a float type

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There are no null values present in the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.0 KB

# %%
#we can map it in the graph
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no missing data present in the data.

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# deescribe() frunction tells the statistical data of our dataset like count tells the number of rows in every column,it gives mean,Standarddeviation,min and max values,and the quartiles data,There is a gap between 75% and max for ERA,SHO and E.

# %% [markdown]
# # DataVisualization

# %% [markdown]
# Univariate Analysis

# %%
sns.distplot(df['R'])
df['R'].value_counts()
df['R'].max()
# Out:
# 891

# %% [markdown]
# Most of the runs are scored in between 570 to 780
# maximum runs scored is 891

# %%
sns.distplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# All the features are normally distributed to themselves

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='R',data=df)
plt.xlabel('Wins')
plt.ylabel('Runs')
plt.title('Runs vs wins')
# Out:
# Text(0.5, 1.0, 'Runs vs wins')

# %% [raw]
# Here we can seee wins and runs are not linearly distributed
# Number of wins are higher at nearly 650 runs
# Number of Runs is a good factor to predict the wins

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='AB',data=df)
plt.xlabel('Wins')
plt.ylabel('AtBats')
plt.title('ATBATs vs wins')
df['AB'].max()
# Out:
# 5649

# %% [markdown]
# There is no relation between Atbats and wins means data points are not scattered well

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='H',data=df)
plt.xlabel('Wins')
plt.ylabel('Hits')
plt.title('Hits vs wins')
df['H'].max()
# Out:
# 1515

# %%
The maximum number of wins between 1375 to 1400
# Out:
#   File "<ipython-input-25-bd85f63b7cf6>", line 1
#     The maximum number of wins between 1375 to 1400
#         ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='2B',data=df)
plt.xlabel('Wins')
plt.ylabel('DoubleRuns')
plt.title('DoubleRuns vs wins')
df['2B'].max()

# %% [markdown]
# As DobleRuns are increasing wins are increasing

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='3B',data=df)
plt.xlabel('Wins')
plt.ylabel('3B')
plt.title('Triple vs wins')
df['3B'].max()

# %% [markdown]
# As some points of triples are incresed wins increased but not all the times

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='BB',data=df)
plt.xlabel('Wins')
plt.ylabel('walks')
plt.title('BB vs wins')
df['BB'].max()
# Out:
# 570

# %% [markdown]
# wins and walks shows a positive relation

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='SO',data=df)
plt.xlabel('Wins')
plt.ylabel('SO')
plt.title('SO vs wins')
df['SO'].max()
# Out:
# 1518

# %% [markdown]
# Strikeouts is correlated with winsmaximum stikeout is at 1518

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='SB',data=df)
plt.xlabel('Wins')
plt.ylabel('SB')
plt.title('SB vs wins')
df['SB'].max()
# Out:
# 134

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='RA',data=df)
plt.xlabel('Wins')
plt.ylabel('RA')
plt.title('RA vs wins')
df['RA'].max()
# Out:
# 844

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='ERA',data=df)
plt.xlabel('Wins')
plt.ylabel('ERA')
plt.title('ERA vs wins')
df['ERA'].max()
# Out:
# 5.04

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='SHO',data=df)
plt.xlabel('Wins')
plt.ylabel('SHO')
plt.title('SHO vs wins')
df['SHO'].max()
# Out:
# 21

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='SV',data=df)
plt.xlabel('Wins')
plt.ylabel('SV')
plt.title('SV vs wins')
df['SV'].max()
# Out:
# 62

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='W',y='E',data=df)
plt.xlabel('Wins')
plt.ylabel('E')
plt.title('E vs wins')
df['E'].max()
# Out:
# 126

# %%
plt.figure(figsize=(14,7))
sns.lineplot(x='ER',y='ERA',data=df)
plt.xlabel('Earned Runs')
plt.ylabel('Earned runs Average')
plt.title('EarnedRuns vs Earned Runs Average')
# Out:
# Text(0.5, 1.0, 'EarnedRuns vs Earned Runs Average')

# %% [markdown]
# There is a positive relation between Earnedruns and EarnedRunsAverage

# %% [markdown]
# Runs and wins are linearly correlated
# AtBats is very weakly related to wins
# Hits are also weakly correlatedto wins
# Doubles are linearly related to wins
# Triples are very weakly,negatively correlated with wins
# HomeRuns has a very low correlation with wins
# walk is less correlated with wins
# StrikeOut is not correlated with wins,the data is left skewed
# StolenBases is not correlated to wins
# Runs Allowed is highly correlated with wins
# EarnedRuns is highly correlated with wins
# ERA is not correlated with wins
# shutouts are highly correlated with wins
# Saves are correlated to wins
# Errors are not correlated to wins

# %% [markdown]
# The number of Runs,HomeRuns,Doubles,Saves,Shutouts,and walks are highly positively linearly correlated
# StolenBases,RunsAllowed,EarnedRuns are highly negatively correlated
# The remaining features are less are not correlated with wins

# %% [markdown]
# # MultivariateAnalysis

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Runs and wins are linearly correlated 43%
# AtBats is very weakly related to wins
# Hits are also weakly correlatedto wins
# Doubles are linearly related to wins 43%
# Triples are very weakly,negatively correlated with wins
# HomeRuns has a very low correlation with wins 31%
# walk is less correlated with wins40%
# StrikeOut is not correlated with wins,the data is left skewed
# StolenBases is not correlated to wins
# Runs Allowed is highly correlated with wins
# EarnedRuns is highly correlated with wins
# ERA is not correlated with wins
# shutouts are highly correlated with wins 47%
# Saves are highly correlated to wins 67%
# Errors are not correlated to wins

# %% [markdown]
# ER with RA is 99% correlated
# ERA with RA is also 99% correalted
# Means multicollinearity exists

# %%
plt.figure(figsize=(25,10))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='skyblue')
plt.xlabel('Features')
plt.ylabel('columns with target names')
plt.title('correlation')
plt.show()

# %% [markdown]
# From the correlation matrix and from the graph, ER,RA,ERA have the strongest correlation with wins but in negative nature
# In poitive side SV has the highest correlation of 0.67 followed by BB,SHO,R,2B all above 0.4
# ER,RA and ERA are very negatively correlated with wins but they showed highest correlation amongest themselves of over 0.99

# %% [markdown]
# # Checking for Outliers

# %%
df.plot(kind='box',subplots=True,figsize=(14,7))
# Out:
# W         AxesSubplot(0.125,0.125;0.0383663x0.755)
# R       AxesSubplot(0.17104,0.125;0.0383663x0.755)
# AB     AxesSubplot(0.217079,0.125;0.0383663x0.755)
# H      AxesSubplot(0.263119,0.125;0.0383663x0.755)
# 2B     AxesSubplot(0.309158,0.125;0.0383663x0.755)
# 3B     AxesSubplot(0.355198,0.125;0.0383663x0.755)
# HR     AxesSubplot(0.401238,0.125;0.0383663x0.755)
# BB     AxesSubplot(0.447277,0.125;0.0383663x0.755)
# SO     AxesSubplot(0.493317,0.125;0.0383663x0.755)
# SB     AxesSubplot(0.539356,0.125;0.0383663x0.755)
# RA     AxesSubplot(0.585396,0.125;0.0383663x0.755)
# ER     AxesSubplot(0.631436,0.125;0.0383663x0.755)
# ERA    AxesSubplot(0.677475,0.125;0.0383663x0.755)
# CG     AxesSubplot(0.723515,0.125;0.0383663x0.755)
# SHO    AxesSubplot(0.769554,0.125;0.0383663x0.755)
# SV     AxesSubplot(0.815594,0.125;0.0383663x0.755)
# E      AxesSubplot(0.861634,0.125;0.0383663x0.755)
# dtype: object

# %% [markdown]
# columns ERA,SHO,SV and E having the outliers we should remove it

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df_new.shape
# Out:
# (29, 17)

# %%
data_loss=df.shape[0]-df_new.shape[0]
data_loss
# Out:
# 1

# %%
data_loss=((30-29)/30)*100
data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# data_loss is 3% which is acceptable

# %% [markdown]
# # seperating columns into features and Target

# %%
x=df_new.drop('W',axis=1)
y=df_new['W']

# %% [markdown]
# # Transforming data to remove skewness we using powertransform method

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,'yeo-johnson')
x
# Out:
# array([[ 9.62543504e-01,  8.38257983e-01,  4.16333634e-16,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052224e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01, -6.92877447e-01, -2.49800181e-16,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800488e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01,
#         -5.40819806e-01],
#        [-3.12105130e-01, -1.11045984e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213881e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01,
#         -1.32612477e+00],
# ...

# %%
pd.DataFrame(x).skew()
# Out:
# 0    -0.024842
# 1     0.081092
# 2     0.000000
# 3    -0.052793
# 4    -0.075139
# 5     0.000448
# 6    -0.008572
# 7     0.051530
# 8    -0.009570
# 9    -0.011974
# 10   -0.004988
# 11   -0.000401
# 12   -0.045947
# 13    0.000529
# 14   -0.000925
# 15    0.065585
# dtype: float64

# %% [markdown]
# The skewness is present inbetween +/-0.5

# %% [markdown]
# # Scaling the data using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 9.62543504e-01,  8.39431267e-01,  1.65963137e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052224e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01, -6.91704164e-01, -9.59650790e-01,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800488e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01,
#         -5.40819806e-01],
#        [-3.12105130e-01, -1.10928655e+00,  2.25800186e-02,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213881e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01,
#         -1.32612477e+00],
# ...

# %% [markdown]
# Here we have transformed all the columns into same scale

# %% [markdown]
# # checking VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x,i) for i in range(x.shape[1])]
vif["Features"]=pd.DataFrame(x).columns
vif
# Out:
#             vif  Features
# 0      7.174699         0
# 1     17.946303         1
# 2      8.927245         2
# 3      3.513904         3
# 4      3.046069         4
# 5      9.053582         5
# 6      3.344263         6
# 7      2.987141         7
# 8      2.263837         8
# 9    231.287965         9
# 10  2261.595286        10
# 11  1626.559924        11
# 12     2.550556        12
# 13     3.416323        13
# 14     5.849808        14
# 15     2.124254        15

# %%
df_new.drop('RA',axis=1,inplace=True)

# %%
#finding the variables based on the cutoff value of VIF 5

# %%
final_data=vif[vif.vif>5].reset_index(drop=True)
final_data
# Out:
#            vif  Features
# 0     7.174699         0
# 1    17.946303         1
# 2     8.927245         2
# 3     9.053582         5
# 4   231.287965         9
# 5  2261.595286        10
# 6  1626.559924        11
# 7     5.849808        14

# %% [markdown]
# # Model Building

# %% [markdown]
# Here our dataset is continuous type so we use LinearRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
lr=LinearRegression()

# %%
for i in range(0,30):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At Randomstate {i} the training accuracy is:",r2_score(y_train,pred_train))
    print(f"At Randomstate {i} the testing accuracy is:",r2_score(y_test,pred_test))
    print("\n")
# Out:
# At Randomstate 0 the training accuracy is: 0.9727595503065152
# At Randomstate 0 the testing accuracy is: 0.5553282532110224
#
#
# At Randomstate 1 the training accuracy is: 0.9675967143381
# At Randomstate 1 the testing accuracy is: 0.7642532372789549
#
#
# At Randomstate 2 the training accuracy is: 0.9596273996421913
# At Randomstate 2 the testing accuracy is: -0.06251382657807025
#
#
# At Randomstate 3 the training accuracy is: 0.9573723515760982
# At Randomstate 3 the testing accuracy is: 0.8698442833057525
#
#
# At Randomstate 4 the training accuracy is: 0.9638191724273177
# At Randomstate 4 the testing accuracy is: 0.6905620543507792
#
#
# At Randomstate 5 the training accuracy is: 0.9642482535204889
# At Randomstate 5 the testing accuracy is: 0.621063010110875
#
#
# At Randomstate 6 the training accuracy is: 0.9577403568375443
# At Randomstate 6 the testing accuracy is: 0.79860424827677
#
#
# At Randomstate 7 the training accuracy is: 0.9609788595390837
# ...

# %%
pred_test=lr.predict(x_test)

# %%
r2_score(pred_test,y_test)
# Out:
# 0.8350465938819623

# %%
plt.figure(figsize=(14,7))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actualwins",fontsize=20)
plt.ylabel("predictedwins",fontsize=20)
plt.show()

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
def regressor(model,x,y):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=3)
    model.fit(x_train,y_train)
    pred=model.predict(x_test)
    print("MeanSquaredError is:",mean_squared_error(y_test,pred))
    print("MeanAbsoluteError is:",mean_absolute_error(y_test,pred))
    print("r2_score is:",r2_score(y_test,pred))
    print("Cross_validation_score is",cross_val_score(model,x,y,cv=5).mean())

# %% [markdown]
# # LinearRegression

# %%
model=LinearRegression()
regressor(model,x,y)
# Out:
# MeanSquaredError is: 22.328936286213178
# MeanAbsoluteError is: 3.8180211531176056
# r2_score is: 0.8698442833057523
# Cross_validation_score is 0.0887204833234754

# %% [markdown]
# # Lasso

# %%
model=Lasso(alpha=0.0001)
regressor(model,x,y)
# Out:
# MeanSquaredError is: 16.297160954274805
# MeanAbsoluteError is: 3.3937519740487794
# r2_score is: 0.9050035954737867
# Cross_validation_score is 0.28047479337699766

# %% [markdown]
# # Ridge

# %%
model=Ridge(alpha=0.0001)
regressor(model,x,y)
# Out:
# MeanSquaredError is: 22.114737953167687
# MeanAbsoluteError is: 3.808479879504683
# r2_score is: 0.8710928487185822
# Cross_validation_score is 0.1003439907572798

# %% [markdown]
# # ElasticNet

# %%
model=ElasticNet(alpha=0.0001)
regressor(model,x,y)
# Out:
# MeanSquaredError is: 16.429167532923714
# MeanAbsoluteError is: 3.3994815983663806
# r2_score is: 0.9042341270749266
# Cross_validation_score is 0.2872735245434136

# %% [markdown]
# # DecisionTreeRegressor

# %%
model=DecisionTreeRegressor()
regressor(model,x,y)
# Out:
# MeanSquaredError is: 68.66666666666667
# MeanAbsoluteError is: 7.666666666666667
# r2_score is: 0.599740932642487
# Cross_validation_score is -2.1430081389378315

# %% [markdown]
# # RandomForestRegressor

# %%
model=RandomForestRegressor()
regressor(model,x,y)
# Out:
# MeanSquaredError is: 43.3039166666667
# MeanAbsoluteError is: 6.1350000000000025
# r2_score is: 0.7475807966321242
# Cross_validation_score is -0.5824134009342739

# %% [markdown]
# # KNN

# %%
model=KNeighborsRegressor()
regressor(model,x,y)
# Out:
# MeanSquaredError is: 75.72
# MeanAbsoluteError is: 8.066666666666668
# r2_score is: 0.5586269430051813
# Cross_validation_score is -0.007053192190609026

# %% [markdown]
# # GradientBoostingRegressor

# %%
model=GradientBoostingRegressor()
regressor(model,x,y)
# Out:
# MeanSquaredError is: 25.636851864778027
# MeanAbsoluteError is: 4.410059744686973
# r2_score is: 0.8505623919799208
# Cross_validation_score is -1.3814141011188112

# %% [markdown]
# # AdaBoostRegressor

# %%
model=AdaBoostRegressor()
regressor(model,x,y)
# Out:
# MeanSquaredError is: 44.73
# MeanAbsoluteError is: 6.166666666666667
# r2_score is: 0.7392681347150258
# Cross_validation_score is -0.5183950403788866

# %% [markdown]
# # HyperParameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
params={'alpha':[1.0,0.1,0.01,0.001],
        
        'fit_intercept':[True,False],
        
        'normalize':[False],
        
        'precompute':[False],
        
        'copy_X':[True,False],
        
        'random_state':[None],
        
        'selection':['cyclic']
       }
l1=Lasso()
gs=GridSearchCV(l1,params)
gs.fit(x,y)
print(gs.best_params_)
# Out:
# {'alpha': 1.0, 'copy_X': True, 'fit_intercept': True, 'normalize': False, 'precompute': False, 'random_state': None, 'selection': 'cyclic'}

# %%
l=Lasso(alpha=1.0, copy_X= True, fit_intercept=True,normalize=False,precompute=False, random_state=None, selection= 'cyclic')
l.fit(x,y)
l.score(x_train,y_train)
pred=l.predict(x_test)

l1=r2_score(y_test,pred)
print('r2_score',l1*100)
lscore=cross_val_score(l,x,y,cv=5)
lc=lscore.mean()
print('crossvalscore:',lc*100)
# Out:
# r2_score 85.37312236785046
# crossvalscore: 51.006877467575315

# %%
#Testing

# %%
df=pd.DataFrame({"Actual":y_test,"Predicted":pred})
df
# Out:
#     Actual  Predicted
# 17      97  90.644049
# 21      83  85.273251
# 19      64  69.903392
# 23      67  69.652689
# 27      79  82.547696
# 3       76  74.150122

# %% [markdown]
# # we are getting r2_score 85.37 and cross_val_score51 for LassoRegressor so,we accept this model

# %% [markdown]
# # Saving the model

# %%
import pickle
filename='BaseballWinsPrediction.pkl'
pickle.dump(l,open(filename,'wb'))
